# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

#Load dataset
df_boston = datasets.load_boston()
data = df_boston.data
target = df_boston.target
print("Features: ", df_boston.feature_names)
print("Data size: ", data.shape)
print("Target size: ", target.shape)
# Out:
# Features:  ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# Data size:  (506, 13)
# Target size:  (506,)

# %%
def estimate_coef(x, y): 
    n = np.size(x)

    # mean of x and y vector 
    m_x, m_y = np.mean(x), np.mean(y) 

    # calculating cross-deviation and deviation about x 
    SS_xy = np.sum(y*x) - n*m_y*m_x 
    SS_xx = np.sum(x*x) - n*m_x*m_x 

    # calculating regression coefficients 
    k = SS_xy / SS_xx 
    b = m_y - k*m_x 

    return(b, k)

# %%
n = data.shape[1]
b, k = np.zeros(n), np.zeros(n)
for i in range(0,n):
    b[i], k[i]= estimate_coef(data[:,i], target)
    print(df_boston.feature_names[i] ,b[i], k[i])
# Out:
# CRIM 24.03310617412388 -0.41519027791509133
# ZN 20.917579117799832 0.14213999415535425
# INDUS 29.754896511928482 -0.6484900536157144
# CHAS 22.093842887473468 6.346157112526532
# NOX 41.34587446797342 -33.9160550086614
# RM -34.67062077643811 9.102108981180239
# AGE 30.978677762618062 -0.12316272123568002
# DIS 18.390088330493413 1.0916130158411026
# RAD 26.3821283622724 -0.4030953955525316
# TAX 32.970654493666345 -0.02556809948198737
# PTRATIO 62.3446274748336 -2.157175296061016
# B 10.551034138417227 0.03359306011501342
# LSTAT 34.553840879383145 -0.950049353757994

# %%
#Importing Package 
import sys
print('Python: {}'.format(sys.version))
import numpy
import pandas
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import numpy as np
import warnings
# Out:
# Python: 3.7.5 (default, Oct 25 2019, 15:51:11)
# [GCC 7.3.0]

# %%
n = data.shape[1]
for i in range(0,n):
    plt.figure()
    fig = plt.figure()
    ax = plt.axes()
    plt.title(df_boston.feature_names[i])
    plt.xlabel(df_boston.feature_names[i])
    plt.ylabel("Price");
    plt.scatter(data[:,i], target)
    plt.plot(data[:,i], (k[i]*data[:,i])  +b[i], linestyle='solid', color='k')
# Out:
# /home/sultan/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/sultan/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.
